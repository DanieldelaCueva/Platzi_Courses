# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.random.randint(1,50,100)

# %% [markdown]
# Histogram

# %%
plt.hist(data, bins=50)
# Out:
# (array([1., 4., 4., 3., 3., 2., 1., 2., 0., 1., 2., 1., 2., 2., 3., 5., 0.,
#         3., 5., 2., 5., 1., 1., 0., 2., 3., 1., 3., 2., 3., 2., 2., 3., 0.,
#         2., 0., 2., 0., 1., 4., 5., 2., 0., 1., 0., 2., 2., 2., 1., 2.]),
#  array([ 1.  ,  1.94,  2.88,  3.82,  4.76,  5.7 ,  6.64,  7.58,  8.52,
#          9.46, 10.4 , 11.34, 12.28, 13.22, 14.16, 15.1 , 16.04, 16.98,
#         17.92, 18.86, 19.8 , 20.74, 21.68, 22.62, 23.56, 24.5 , 25.44,
#         26.38, 27.32, 28.26, 29.2 , 30.14, 31.08, 32.02, 32.96, 33.9 ,
#         34.84, 35.78, 36.72, 37.66, 38.6 , 39.54, 40.48, 41.42, 42.36,
#         43.3 , 44.24, 45.18, 46.12, 47.06, 48.  ]),
#  <BarContainer object of 50 artists>)

# %%
plt.hist(data, bins=50, histtype='step')
# Out:
# (array([1., 4., 4., 3., 3., 2., 1., 2., 0., 1., 2., 1., 2., 2., 3., 5., 0.,
#         3., 5., 2., 5., 1., 1., 0., 2., 3., 1., 3., 2., 3., 2., 2., 3., 0.,
#         2., 0., 2., 0., 1., 4., 5., 2., 0., 1., 0., 2., 2., 2., 1., 2.]),
#  array([ 1.  ,  1.94,  2.88,  3.82,  4.76,  5.7 ,  6.64,  7.58,  8.52,
#          9.46, 10.4 , 11.34, 12.28, 13.22, 14.16, 15.1 , 16.04, 16.98,
#         17.92, 18.86, 19.8 , 20.74, 21.68, 22.62, 23.56, 24.5 , 25.44,
#         26.38, 27.32, 28.26, 29.2 , 30.14, 31.08, 32.02, 32.96, 33.9 ,
#         34.84, 35.78, 36.72, 37.66, 38.6 , 39.54, 40.48, 41.42, 42.36,
#         43.3 , 44.24, 45.18, 46.12, 47.06, 48.  ]),
#  [<matplotlib.patches.Polygon at 0x22690b86250>])

# %% [markdown]
# Boxplot

# %%
data = np.append(data,200)
plt.boxplot(data, vert=False, patch_artist=True, notch=True, showfliers=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22690d5c970>,
#   <matplotlib.lines.Line2D at 0x22690d5cd00>],
#  'caps': [<matplotlib.lines.Line2D at 0x22690d5ce80>,
#   <matplotlib.lines.Line2D at 0x22690d6b220>],
#  'boxes': [<matplotlib.patches.PathPatch at 0x22690d5c5e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x22690d6b580>],
#  'fliers': [],
#  'means': []}

# %% [markdown]
# Scatter

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
area = (30 * np.random.rand(N)) **2
colors = np.random.rand(N)

# %%
plt.scatter(x,y, s=area, c=colors, marker='o', alpha=0.5)
plt.show()

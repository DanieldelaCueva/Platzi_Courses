# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)
y = np.sin(x)

# %%
fig, axes = plt.subplots()
axes.plot(x,y,'b')

# %%
fig, axes = plt.subplots(nrows=2, ncols=4)
axes[0].plot(x,y,'b')
axes[1].plot(y,x,'r')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Jesús de la Cueva\Documents\GitHub\Platzi_Courses\Escuela_DS_IA\16-curso_matplotlib-seaborn\matplotlib\mat_subplots.ipynb Celda 4 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Jes%C3%BAs%20de%20la%20Cueva/Documents/GitHub/Platzi_Courses/Escuela_DS_IA/16-curso_matplotlib-seaborn/matplotlib/mat_subplots.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> fig, axes = plt.subplots(nrows=2, ncols=4)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Jes%C3%BAs%20de%20la%20Cueva/Documents/GitHub/Platzi_Courses/Escuela_DS_IA/16-curso_matplotlib-seaborn/matplotlib/mat_subplots.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> axes[0].plot(x,y,'b')
#       <a href='vscode-notebook-cell:/c%3A/Users/Jes%C3%BAs%20de%20la%20Cueva/Documents/GitHub/Platzi_Courses/Escuela_DS_IA/16-curso_matplotlib-seaborn/matplotlib/mat_subplots.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> axes[1].plot(y,x,'r')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

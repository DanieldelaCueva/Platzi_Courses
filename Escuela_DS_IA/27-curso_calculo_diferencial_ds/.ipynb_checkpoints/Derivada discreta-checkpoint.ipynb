# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10,10,1000)

def f(x):
    return x**2

def df(f):
    h = 0.000000001
    return (f(x+h) - f(x)) / h

plt.plot(x, f(x), 'b')
plt.plot(x, df(f), 'r')
plt.grid()
